# %%
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt

import os
import time

# %% [markdown]
# # Dataset Preprocessing

# %% [markdown]
# Load Dataset

# %%
folder_dir = "/content/drive/MyDrive/Projects/CERN openlab Summer Student 2021/"

X_train = np.load(folder_dir + "dataset/optimal/x_data_optimal_norm_7.20e+05_train.npy")
y_train = np.load(folder_dir + "dataset/optimal/y_data_optimal_norm_7.20e+05_train.npy")
X_val = np.load(folder_dir + "dataset/optimal/x_data_optimal_norm_7.20e+05_valid.npy")
y_val = np.load(folder_dir + "dataset/optimal/y_data_optimal_norm_7.20e+05_valid.npy")
X_test = np.load(folder_dir + "dataset/optimal/x_data_optimal_norm_7.20e+05_test.npy")
y_test = np.load(folder_dir + "dataset/optimal/y_data_optimal_norm_7.20e+05_test.npy")

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)
# Out:
# Train shape: (1152000, 67) (1152000,)
# Validation shape: (144000, 67) (144000,)
# Test shape: (144000, 67) (144000,)

# %% [markdown]
# Take only the positive class (y = 1): the events which the Higgs are being produced, as we are not interested in reproducing the background data (for now).

# %%
X_train = X_train[y_train == 1]
X_val = X_val[y_val == 1]
X_test = X_test[y_test == 1]

print("Train shape:", X_train.shape)
print("Validation shape:", X_val.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (576290, 67)
# Validation shape: (71942, 67)
# Test shape: (71768, 67)

# %%
a = X_train[X_train[:, 7] == 0]
a = a[a[:, 15] == 0]
a = a[a[:, 23] == 0]
a = a[a[:, 31] == 0]
a = a[a[:, 39] == 0]
a = a[a[:, 47] == 0]
a = a[a[:, 55] == 0]

len(a)
# Out:
# 260

# %% [markdown]
# The 67 features in the dataset are arranged as follow:
# $$
# \text{1st jet, 2nd jet, 3rd jet, ..., 7th jet, MET, lepton}
# $$
# The jets in total have $7x8 = 56$ features, where every jet has 8 features, which are ordered as:
# $$
# \text{["pt", "eta", "phi", "en", "px", "py", "pz", "btag"]}
# $$
# MET has 4 features, which are ordered as:
# $$
# \text{"phi", "pt", "px", "py"]}
# $$
# lepton has 7 features, which are ordered as:
# $$
# \text{["pt", "eta", "phi", "en", "px", "py", "pz"]}
# $$
#
# Notes:
# - MET = missing transverse momentum
# - lepton = (electron or muon)
# - btag = either 1 or 0, 1 means the jet is the b-jet, 0 otherwise

# %% [markdown]
# We then preprocess the training set so that the training set contains:
#
# 1. Only the two b-jets (jets with $\text{btag} = 1$) with the highest $\text{"pt"}$.
# 2. For every jets, only keep the $\text{"pt", "eta", "phi", "en"}$ features.
#
# In total, the final training set should have $2x4 = 8$ features.

# %%
total_jets = 7  ## number of jets in the dataset
features_wanted = 8  ## number of features to be used during the training

selected_events = np.zeros((1, features_wanted))

for i in range (total_jets-1):
    for j in range(i+1, total_jets):
        index_temp = np.where(np.logical_and(X_train[:, 8*i + 7] == 1, X_train[:, 8*j + 7] == 1))[0]
        temp = np.concatenate((X_train[index_temp, 8*i:(8*i+4)], X_train[index_temp, 8*j:(8*j+4)]), axis=1)
        selected_events = np.concatenate((selected_events, temp), axis=0)
        print(i, j, len(temp))

        X_train = np.delete(X_train, index_temp, axis=0)

X_train = np.delete(selected_events, 0, axis=0)

X_train.shape
# Out:
# 0 1 159667
# 0 2 83610
# 0 3 38949
# 0 4 17209
# 0 5 6790
# 0 6 2763
# 1 2 85366
# 1 3 42179
# 1 4 18801
# 1 5 7646
# 1 6 3090
# 2 3 39229
# 2 4 17406
# 2 5 7334
# 2 6 2889
# 3 4 15368
# 3 5 6354
# 3 6 2513
# 4 5 5342
# 4 6 2060
# 5 6 1670
# (566235, 8)

# %% [markdown]
# # Data Visualization

# %%
fig, ax = plt.subplots(2,4,figsize=(20, 10))
fig.tight_layout(pad=1.7)
plt.subplots_adjust(bottom=0.05, top=0.9)

features_name = ["$p_{t1}$","$\eta_{1}$","$\phi_{1}$","$E_{1}$","$p_{t2}$","$\eta_{2}$","$\phi_{2}$","$E_{2}$"]

for i in range(features_wanted):
    # real signal
    ax[int(i/4),i%4].hist(X_train[:,i],  alpha=0.5, color='r', label='Real Signal', bins=80)
    ax[int(i/4),i%4].title.set_text(features_name[i])

plt.legend()
plt.show()

# %% [markdown]
# # Model Set Up

# %% [markdown]
# The architecture of the (modified) DijetGAN.
#
# ![20210709_015554.jpg](data:image/jpeg;base64,...)

# %%
def make_generator_model():
    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Reshape((8,8,2), input_shape=(128,)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.Conv2DTranspose(32, (5, 5), strides=(1,1), padding='same', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.Conv2DTranspose(16, (5,5), strides=(1,1), padding='same', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(8, activation='tanh'))

    return model

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Dense(128, input_shape=(8,)))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Reshape((8,8,2)))

    model.add(tf.keras.layers.Conv2D(64, (5, 5), strides=(1, 1), padding='same', use_bias=False,))
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same'))
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.Conv2D(16, (5, 5), strides=(1, 1), padding='same'))
    model.add(tf.keras.layers.LeakyReLU())

    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    return model

# %%
input_vector = tf.random.uniform([len(X_train), 128], minval=0, maxval=1, seed=None)
input_vector.shape
# Out:
# TensorShape([566235, 128])

# %%
model_gen = make_generator_model()
fake_data = model_gen.predict(input_vector)
print(fake_data.shape)
#tf.keras.utils.plot_model(model_gen, rankdir='TB')
# Out:
# (566235, 8)

# %%
model_disc = make_discriminator_model()
#print(model_disc(fake_data).shape)
#tf.keras.utils.plot_model(model_disc, rankdir='TB')

# %%
fig, ax = plt.subplots(2,4,figsize=(20, 10))
fig.tight_layout(pad=1.7)
plt.subplots_adjust(bottom=0.05, top=0.9)

features_name = ["$p_{t1}$","$\eta_{1}$","$\phi_{1}$","$E_{1}$","$p_{t2}$","$\eta_{2}$","$\phi_{2}$","$E_{2}$"]

for i in range(features_wanted):
    # real signal
    ax[int(i/4),i%4].hist(X_train[:,i],  alpha=0.5, color='r', label='Real Signal', bins=80)
    # fake signal
    ax[int(i/4),i%4].hist(fake_data[:,i],  alpha=0.5, color='b', label='Fake Signal', bins=80)

    ax[int(i/4),i%4].title.set_text(features_name[i])

plt.legend()
plt.show()

# %%
# This method returns a helper function to compute cross entropy and mse loss
cross_entropy = tf.keras.losses.BinaryCrossentropy()
mse = tf.keras.losses.MeanSquaredError()

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-5, beta_1=0.5, beta_2=0.9)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-5, beta_1=0.5, beta_2=0.9)

# %%
checkpoint_dir = '/content/drive/MyDrive/Projects/CERN openlab Summer Student 2021/classical model'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=model_gen,
                                 discriminator=model_disc)

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(features):
    noise = tf.random.uniform([len(features), 128], minval=0, maxval=1, seed=None)

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_features = model_gen(noise, training=True)

      real_output = model_disc(features, training=True)
      fake_output = model_disc(generated_features, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, model_gen.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, model_disc.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, model_gen.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, model_disc.trainable_variables))

    return gen_loss, disc_loss

# %%
def train(dataset, epochs):
    
    # list container to record epoch losses
    gen_history = []
    disc_history = []

    # epoch/iteration loop
    for epoch in range(epochs):
      start = time.time()

      # list container to record the mini-batch losses
      gen_loss = []
      disc_loss = []

      # train the models in mini-batches (the mini-batches loop)
      for data_batch in dataset:
        gl, dl = train_step(data_batch)
        gen_loss += [gl]
        disc_loss += [dl]
      
      # average the mini-batch losses to get the epoch loss
      gen_loss_mean = np.mean(np.array(gen_loss))
      disc_loss_mean = np.mean(np.array(disc_loss))

      # record the epoch loss
      gen_history += [gen_loss_mean]
      disc_history += [disc_loss_mean]

      # Save the model and epoch losses every 20 epochs
      if (epoch + 1) % 20 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)
        np.savetxt(checkpoint_dir + '/gen_loss.txt', np.array(gen_history))
        np.savetxt(checkpoint_dir + '/disc_loss.txt', np.array(disc_history))

      print ('Time for epoch {} is {} sec. Generator loss: {}, Discriminator loss: {}.'.format(epoch + 1, time.time()-start, gen_loss_mean, disc_loss_mean))

    return gen_history, disc_history

# %%
# Batch and shuffle the data
BUFFER_SIZE = len(X_train)
BATCH_SIZE = 128

train_dataset = tf.data.Dataset.from_tensor_slices(X_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
train_dataset
# Out:
# <BatchDataset shapes: (None, 8), types: tf.float64>

# %%
# Sanity check

i = 0
for data_batch in train_dataset:
  if i == 0:
    print(len(data_batch))
  i += 1

print(i)
print(len(X_train)/128)
# Out:
# 128
# 4424
# 4423.7109375

# %% [markdown]
# # Model Training

# %%
EPOCHS = 500
gen_history, disc_history = train(train_dataset, EPOCHS)

plt.plot(gen_history, label="Generator")
plt.plot(disc_history, label="Discriminator")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()
# Out:
# Time for epoch 1 is 34.12639880180359 sec. Generator loss: 1.335569977760315, Discriminator loss: 0.9842081069946289.
# Time for epoch 2 is 31.416006088256836 sec. Generator loss: 3.6864333152770996, Discriminator loss: 0.5026012063026428.
# Time for epoch 3 is 31.467939138412476 sec. Generator loss: 2.0881388187408447, Discriminator loss: 0.878655195236206.
# Time for epoch 4 is 31.469799280166626 sec. Generator loss: 1.1271378993988037, Discriminator loss: 1.1925190687179565.
# Time for epoch 5 is 31.344090938568115 sec. Generator loss: 0.8518804907798767, Discriminator loss: 1.310014009475708.
# Time for epoch 6 is 31.734344959259033 sec. Generator loss: 0.7760833501815796, Discriminator loss: 1.3417143821716309.
# Time for epoch 7 is 31.308966159820557 sec. Generator loss: 0.7527240514755249, Discriminator loss: 1.3519729375839233.
# Time for epoch 8 is 31.392210960388184 sec. Generator loss: 0.7403331398963928, Discriminator loss: 1.3624624013900757.
# Time for epoch 9 is 31.32507562637329 sec. Generator loss: 0.7308147549629211, Discriminator loss: 1.3680922985076904.
# Time for epoch 10 is 31.2542724609375 sec. Generator loss: 0.7252207398414612, Discriminator loss: 1.3707149028778076.
# Time for epoch 11 is 31.46568989753723 sec. Generator loss: 0.7231748700141907, Discriminator loss: 1.3702874183654785.
# Time for epoch 12 is 31.14091658592224 sec. Generator loss: 0.7223628759384155, Discriminator loss: 1.369193434715271.
# Time for epoch 13 is 31.027751922607422 sec. Generator loss: 0.7273510098457336, Discriminator loss: 1.3664649724960327.
# Time for epoch 14 is 31.072054624557495 sec. Generator loss: 0.7321298122406006, Discriminator loss: 1.3642935752868652.
# Time for epoch 15 is 31.26351571083069 sec. Generator loss: 0.7340056896209717, Discriminator loss: 1.3624002933502197.
# Time for epoch 16 is 31.12527346611023 sec. Generator loss: 0.7398339509963989, Discriminator loss: 1.360418438911438.
# Time for epoch 17 is 31.052268743515015 sec. Generator loss: 0.7432771921157837, Discriminator loss: 1.357515573501587.
# Time for epoch 18 is 30.93362855911255 sec. Generator loss: 0.7362161874771118, Discriminator loss: 1.3596032857894897.
# Time for epoch 19 is 30.463157176971436 sec. Generator loss: 0.7360515594482422, Discriminator loss: 1.3593199253082275.
# Time for epoch 20 is 31.10138463973999 sec. Generator loss: 0.7458786964416504, Discriminator loss: 1.3552156686782837.
# Time for epoch 21 is 30.9259033203125 sec. Generator loss: 0.7417554259300232, Discriminator loss: 1.3548921346664429.
# Time for epoch 22 is 30.949230432510376 sec. Generator loss: 0.7533941864967346, Discriminator loss: 1.3497262001037598.
# Time for epoch 23 is 31.112452030181885 sec. Generator loss: 0.7542269229888916, Discriminator loss: 1.3472439050674438.
# Time for epoch 24 is 30.785637855529785 sec. Generator loss: 0.7572243213653564, Discriminator loss: 1.3450748920440674.
# Time for epoch 25 is 31.1134991645813 sec. Generator loss: 0.7566360831260681, Discriminator loss: 1.345053791999817.
# Time for epoch 26 is 30.743812799453735 sec. Generator loss: 0.7698773741722107, Discriminator loss: 1.3388057947158813.
# Time for epoch 27 is 30.779409646987915 sec. Generator loss: 0.7624763250350952, Discriminator loss: 1.341135859489441.
# Time for epoch 28 is 30.847081661224365 sec. Generator loss: 0.7659372687339783, Discriminator loss: 1.3385447263717651.
# Time for epoch 29 is 30.827157974243164 sec. Generator loss: 0.7404624223709106, Discriminator loss: 1.3490785360336304.
# Time for epoch 30 is 31.14529585838318 sec. Generator loss: 0.7285283207893372, Discriminator loss: 1.3590182065963745.
# Time for epoch 31 is 30.69900155067444 sec. Generator loss: 0.7244455814361572, Discriminator loss: 1.3657498359680176.
# Time for epoch 32 is 30.94952940940857 sec. Generator loss: 0.7178018093109131, Discriminator loss: 1.3742221593856812.
# Time for epoch 33 is 31.028412342071533 sec. Generator loss: 0.7111807465553284, Discriminator loss: 1.3796441555023193.
# Time for epoch 34 is 30.977532386779785 sec. Generator loss: 0.7077549695968628, Discriminator loss: 1.3802287578582764.
# Time for epoch 35 is 30.943748950958252 sec. Generator loss: 0.7068157196044922, Discriminator loss: 1.3787727355957031.
# Time for epoch 36 is 30.83967161178589 sec. Generator loss: 0.706344723701477, Discriminator loss: 1.3781265020370483.
# Time for epoch 37 is 30.92127299308777 sec. Generator loss: 0.7056925892829895, Discriminator loss: 1.377873420715332.
# Time for epoch 38 is 30.893752098083496 sec. Generator loss: 0.7051051259040833, Discriminator loss: 1.3781108856201172.
# Time for epoch 39 is 30.726171255111694 sec. Generator loss: 0.7044685482978821, Discriminator loss: 1.3783177137374878.
# Time for epoch 40 is 31.028886318206787 sec. Generator loss: 0.7037674188613892, Discriminator loss: 1.3787800073623657.
# Time for epoch 41 is 31.02970862388611 sec. Generator loss: 0.7034217715263367, Discriminator loss: 1.3788422346115112.
# Time for epoch 42 is 30.80107283592224 sec. Generator loss: 0.7029094696044922, Discriminator loss: 1.3792481422424316.
# Time for epoch 43 is 31.024046421051025 sec. Generator loss: 0.702341616153717, Discriminator loss: 1.3794245719909668.
# Time for epoch 44 is 31.070957899093628 sec. Generator loss: 0.7023023962974548, Discriminator loss: 1.3794171810150146.
# Time for epoch 45 is 30.303386211395264 sec. Generator loss: 0.7019592523574829, Discriminator loss: 1.3795216083526611.
# Time for epoch 46 is 29.960214614868164 sec. Generator loss: 0.7019761800765991, Discriminator loss: 1.3795496225357056.
# Time for epoch 47 is 30.231286764144897 sec. Generator loss: 0.701615035533905, Discriminator loss: 1.3797411918640137.
# Time for epoch 48 is 30.016075611114502 sec. Generator loss: 0.7016612887382507, Discriminator loss: 1.379552960395813.
# Time for epoch 49 is 29.84833526611328 sec. Generator loss: 0.7016664743423462, Discriminator loss: 1.3795238733291626.
# Time for epoch 50 is 29.64966082572937 sec. Generator loss: 0.7015377283096313, Discriminator loss: 1.3794385194778442.
# Time for epoch 51 is 29.934468030929565 sec. Generator loss: 0.7014217376708984, Discriminator loss: 1.379669189453125.
# Time for epoch 52 is 30.30681800842285 sec. Generator loss: 0.7012360095977783, Discriminator loss: 1.3797078132629395.
# Time for epoch 53 is 29.75324583053589 sec. Generator loss: 0.7013627886772156, Discriminator loss: 1.3795474767684937.
# Time for epoch 54 is 30.14784264564514 sec. Generator loss: 0.7012176513671875, Discriminator loss: 1.3795039653778076.
# Time for epoch 55 is 29.904905319213867 sec. Generator loss: 0.7011300921440125, Discriminator loss: 1.3796662092208862.
# Time for epoch 56 is 30.0555899143219 sec. Generator loss: 0.7010889053344727, Discriminator loss: 1.379659652709961.
# Time for epoch 57 is 30.39506220817566 sec. Generator loss: 0.7011432647705078, Discriminator loss: 1.3795474767684937.
# Time for epoch 58 is 30.210843801498413 sec. Generator loss: 0.7012277245521545, Discriminator loss: 1.3795074224472046.
# Time for epoch 59 is 30.36510992050171 sec. Generator loss: 0.7012395858764648, Discriminator loss: 1.3793712854385376.
# Time for epoch 60 is 30.15606689453125 sec. Generator loss: 0.7011829614639282, Discriminator loss: 1.3794434070587158.
# Time for epoch 61 is 30.324636697769165 sec. Generator loss: 0.701228678226471, Discriminator loss: 1.3794348239898682.
# Time for epoch 62 is 30.40522050857544 sec. Generator loss: 0.7013005614280701, Discriminator loss: 1.3793467283248901.
# Time for epoch 63 is 30.134952306747437 sec. Generator loss: 0.7012298107147217, Discriminator loss: 1.379507303237915.
# Time for epoch 64 is 30.48351764678955 sec. Generator loss: 0.7013817429542542, Discriminator loss: 1.3793448209762573.
# Time for epoch 65 is 30.46811532974243 sec. Generator loss: 0.7012537717819214, Discriminator loss: 1.3795424699783325.
# Time for epoch 66 is 30.230132341384888 sec. Generator loss: 0.701419472694397, Discriminator loss: 1.379380702972412.
# Time for epoch 67 is 30.723167419433594 sec. Generator loss: 0.701277494430542, Discriminator loss: 1.3795490264892578.
# Time for epoch 68 is 30.064332485198975 sec. Generator loss: 0.701315701007843, Discriminator loss: 1.3794974088668823.
# Time for epoch 69 is 30.443159341812134 sec. Generator loss: 0.7013261914253235, Discriminator loss: 1.3794676065444946.
# Time for epoch 70 is 30.028043031692505 sec. Generator loss: 0.7013846635818481, Discriminator loss: 1.3795720338821411.
# Time for epoch 71 is 30.543157815933228 sec. Generator loss: 0.7013083100318909, Discriminator loss: 1.379650592803955.
# Time for epoch 72 is 30.214311599731445 sec. Generator loss: 0.701160728931427, Discriminator loss: 1.3797996044158936.
# Time for epoch 73 is 30.354098796844482 sec. Generator loss: 0.7013649344444275, Discriminator loss: 1.379881501197815.
# Time for epoch 74 is 30.174612522125244 sec. Generator loss: 0.7011398077011108, Discriminator loss: 1.380027174949646.
# Time for epoch 75 is 30.391397953033447 sec. Generator loss: 0.7010751962661743, Discriminator loss: 1.3802393674850464.
# Time for epoch 76 is 30.635217666625977 sec. Generator loss: 0.7009154558181763, Discriminator loss: 1.3804295063018799.
# Time for epoch 77 is 30.580992221832275 sec. Generator loss: 0.7009671330451965, Discriminator loss: 1.3803966045379639.
# Time for epoch 78 is 30.16292667388916 sec. Generator loss: 0.700816810131073, Discriminator loss: 1.3806097507476807.
# Time for epoch 79 is 30.24763536453247 sec. Generator loss: 0.700862467288971, Discriminator loss: 1.3806017637252808.
# Time for epoch 80 is 29.958435535430908 sec. Generator loss: 0.7007659077644348, Discriminator loss: 1.3807172775268555.
# Time for epoch 81 is 30.676918268203735 sec. Generator loss: 0.7004861235618591, Discriminator loss: 1.3810498714447021.
# Time for epoch 82 is 32.844266176223755 sec. Generator loss: 0.7004478573799133, Discriminator loss: 1.3810421228408813.
# Time for epoch 83 is 31.10741090774536 sec. Generator loss: 0.7006099820137024, Discriminator loss: 1.3809622526168823.
# Time for epoch 84 is 34.171945333480835 sec. Generator loss: 0.7003438472747803, Discriminator loss: 1.3812789916992188.
# Time for epoch 85 is 34.42037582397461 sec. Generator loss: 0.7002962231636047, Discriminator loss: 1.381278157234192.
# Time for epoch 86 is 34.638810873031616 sec. Generator loss: 0.7002655267715454, Discriminator loss: 1.3812940120697021.
# Time for epoch 87 is 34.467036962509155 sec. Generator loss: 0.7002533674240112, Discriminator loss: 1.381273627281189.
# Time for epoch 88 is 34.21003770828247 sec. Generator loss: 0.7000810503959656, Discriminator loss: 1.3815687894821167.
# Time for epoch 89 is 34.007853746414185 sec. Generator loss: 0.7000221610069275, Discriminator loss: 1.3815269470214844.
# Time for epoch 90 is 32.678617000579834 sec. Generator loss: 0.7000489830970764, Discriminator loss: 1.3815964460372925.
# Time for epoch 91 is 32.40434741973877 sec. Generator loss: 0.6999334096908569, Discriminator loss: 1.3815875053405762.
# Time for epoch 92 is 32.082237005233765 sec. Generator loss: 0.6998360753059387, Discriminator loss: 1.3817646503448486.
# Time for epoch 93 is 30.40640950202942 sec. Generator loss: 0.6998873949050903, Discriminator loss: 1.381735920906067.
# Time for epoch 94 is 31.55268168449402 sec. Generator loss: 0.6997984647750854, Discriminator loss: 1.3818187713623047.
# Time for epoch 95 is 31.812726736068726 sec. Generator loss: 0.6995927691459656, Discriminator loss: 1.3819385766983032.
# Time for epoch 96 is 30.780245304107666 sec. Generator loss: 0.699512243270874, Discriminator loss: 1.382022738456726.
# Time for epoch 97 is 30.459415435791016 sec. Generator loss: 0.6996724009513855, Discriminator loss: 1.3819319009780884.
# Time for epoch 98 is 30.68365240097046 sec. Generator loss: 0.6995047330856323, Discriminator loss: 1.3819453716278076.
# Time for epoch 99 is 30.647830963134766 sec. Generator loss: 0.6994692087173462, Discriminator loss: 1.38204824924469.
# Time for epoch 100 is 30.292583227157593 sec. Generator loss: 0.6994108557701111, Discriminator loss: 1.382092833518982.
# Time for epoch 101 is 30.67132806777954 sec. Generator loss: 0.6993972063064575, Discriminator loss: 1.3822003602981567.
# Time for epoch 102 is 31.658020496368408 sec. Generator loss: 0.6993193030357361, Discriminator loss: 1.3821361064910889.
# Time for epoch 103 is 32.58986258506775 sec. Generator loss: 0.6993471384048462, Discriminator loss: 1.38217031955719.
# Time for epoch 104 is 31.242347478866577 sec. Generator loss: 0.6993005275726318, Discriminator loss: 1.3821552991867065.
# Time for epoch 105 is 30.419469118118286 sec. Generator loss: 0.6992577314376831, Discriminator loss: 1.3822565078735352.
# Time for epoch 106 is 30.10226821899414 sec. Generator loss: 0.6992612481117249, Discriminator loss: 1.3821567296981812.
# Time for epoch 107 is 30.34995436668396 sec. Generator loss: 0.6992492079734802, Discriminator loss: 1.38221275806427.
# Time for epoch 108 is 30.880070447921753 sec. Generator loss: 0.6992623209953308, Discriminator loss: 1.3822031021118164.
# Time for epoch 109 is 32.38572692871094 sec. Generator loss: 0.6992235779762268, Discriminator loss: 1.3821427822113037.
# Time for epoch 110 is 30.729984521865845 sec. Generator loss: 0.6991074681282043, Discriminator loss: 1.3822816610336304.
# Time for epoch 111 is 31.473581075668335 sec. Generator loss: 0.6991593837738037, Discriminator loss: 1.3821845054626465.
# Time for epoch 112 is 32.67862057685852 sec. Generator loss: 0.6991097331047058, Discriminator loss: 1.38222074508667.
# Time for epoch 113 is 32.50429153442383 sec. Generator loss: 0.6990504264831543, Discriminator loss: 1.382215142250061.
# Time for epoch 114 is 31.49821162223816 sec. Generator loss: 0.6990655064582825, Discriminator loss: 1.3822566270828247.
# Time for epoch 115 is 30.6683669090271 sec. Generator loss: 0.6990527510643005, Discriminator loss: 1.3821824789047241.
# Time for epoch 116 is 30.242024183273315 sec. Generator loss: 0.6990702152252197, Discriminator loss: 1.3821873664855957.
# Time for epoch 117 is 30.126739501953125 sec. Generator loss: 0.6990906000137329, Discriminator loss: 1.3821080923080444.
# Time for epoch 118 is 30.124393463134766 sec. Generator loss: 0.6990921497344971, Discriminator loss: 1.3820823431015015.
# Time for epoch 119 is 29.908201932907104 sec. Generator loss: 0.6991036534309387, Discriminator loss: 1.3820635080337524.
# Time for epoch 120 is 30.76822566986084 sec. Generator loss: 0.6989559531211853, Discriminator loss: 1.3821769952774048.
# Time for epoch 121 is 30.176902532577515 sec. Generator loss: 0.6990318894386292, Discriminator loss: 1.3821780681610107.
# Time for epoch 122 is 30.400295972824097 sec. Generator loss: 0.6990571618080139, Discriminator loss: 1.382081389427185.
# Time for epoch 123 is 30.143425703048706 sec. Generator loss: 0.6990317106246948, Discriminator loss: 1.382155179977417.
# Time for epoch 124 is 29.853895902633667 sec. Generator loss: 0.6991432309150696, Discriminator loss: 1.381998896598816.
# Time for epoch 125 is 30.207036018371582 sec. Generator loss: 0.6990109086036682, Discriminator loss: 1.3819756507873535.
# Time for epoch 126 is 30.4123637676239 sec. Generator loss: 0.6990979909896851, Discriminator loss: 1.382026195526123.
# Time for epoch 127 is 33.960286378860474 sec. Generator loss: 0.6990717053413391, Discriminator loss: 1.3820300102233887.
# Time for epoch 128 is 33.28790545463562 sec. Generator loss: 0.6989594101905823, Discriminator loss: 1.38215970993042.
# Time for epoch 129 is 31.337033987045288 sec. Generator loss: 0.6990485787391663, Discriminator loss: 1.3819953203201294.
# Time for epoch 130 is 30.93509817123413 sec. Generator loss: 0.699012041091919, Discriminator loss: 1.3820892572402954.
# Time for epoch 131 is 30.37486743927002 sec. Generator loss: 0.6991052627563477, Discriminator loss: 1.3820021152496338.
# Time for epoch 132 is 30.562288522720337 sec. Generator loss: 0.6990077495574951, Discriminator loss: 1.3820343017578125.
# Time for epoch 133 is 30.262529611587524 sec. Generator loss: 0.6991361379623413, Discriminator loss: 1.381903052330017.
# Time for epoch 134 is 29.89282202720642 sec. Generator loss: 0.6990784406661987, Discriminator loss: 1.382023811340332.
# Time for epoch 135 is 30.054149627685547 sec. Generator loss: 0.6989817023277283, Discriminator loss: 1.3820689916610718.
# Time for epoch 136 is 29.915757656097412 sec. Generator loss: 0.6990452408790588, Discriminator loss: 1.3819416761398315.
# Time for epoch 137 is 30.314706802368164 sec. Generator loss: 0.6990957856178284, Discriminator loss: 1.3819221258163452.
# Time for epoch 138 is 29.854036569595337 sec. Generator loss: 0.6991247534751892, Discriminator loss: 1.382022500038147.
# Time for epoch 139 is 30.063384532928467 sec. Generator loss: 0.6990624666213989, Discriminator loss: 1.3819862604141235.
# Time for epoch 140 is 30.335955381393433 sec. Generator loss: 0.6990416049957275, Discriminator loss: 1.3820078372955322.
# Time for epoch 141 is 30.20943856239319 sec. Generator loss: 0.698991596698761, Discriminator loss: 1.381947636604309.
# Time for epoch 142 is 30.065986156463623 sec. Generator loss: 0.6990104913711548, Discriminator loss: 1.3820362091064453.
# Time for epoch 143 is 29.907989263534546 sec. Generator loss: 0.6991870999336243, Discriminator loss: 1.3817965984344482.
# Time for epoch 144 is 30.05673360824585 sec. Generator loss: 0.6990689635276794, Discriminator loss: 1.3819785118103027.
# Time for epoch 145 is 29.792285680770874 sec. Generator loss: 0.6990151405334473, Discriminator loss: 1.3820081949234009.
# Time for epoch 146 is 30.246582984924316 sec. Generator loss: 0.6989811062812805, Discriminator loss: 1.382055401802063.
# Time for epoch 147 is 29.940446376800537 sec. Generator loss: 0.6990285515785217, Discriminator loss: 1.3819282054901123.
# Time for epoch 148 is 29.956594467163086 sec. Generator loss: 0.6991753578186035, Discriminator loss: 1.3817908763885498.
# Time for epoch 149 is 29.964061498641968 sec. Generator loss: 0.6990849375724792, Discriminator loss: 1.3819572925567627.
# Time for epoch 150 is 29.85853624343872 sec. Generator loss: 0.6990033984184265, Discriminator loss: 1.3820321559906006.
# Time for epoch 151 is 30.208998918533325 sec. Generator loss: 0.6989690661430359, Discriminator loss: 1.3820971250534058.
# Time for epoch 152 is 29.95666480064392 sec. Generator loss: 0.6991570591926575, Discriminator loss: 1.3817273378372192.
# Time for epoch 153 is 29.822643280029297 sec. Generator loss: 0.699037492275238, Discriminator loss: 1.3819036483764648.
# Time for epoch 154 is 29.959880113601685 sec. Generator loss: 0.699124276638031, Discriminator loss: 1.3817687034606934.
# Time for epoch 155 is 29.860077619552612 sec. Generator loss: 0.698991596698761, Discriminator loss: 1.382005214691162.
# Time for epoch 156 is 30.202768325805664 sec. Generator loss: 0.6990708708763123, Discriminator loss: 1.3819164037704468.
# Time for epoch 157 is 30.141035795211792 sec. Generator loss: 0.699016809463501, Discriminator loss: 1.381927490234375.
# Time for epoch 158 is 30.01149034500122 sec. Generator loss: 0.6991603970527649, Discriminator loss: 1.3819321393966675.
# Time for epoch 159 is 30.091119050979614 sec. Generator loss: 0.6990976929664612, Discriminator loss: 1.3819416761398315.
# Time for epoch 160 is 30.502905130386353 sec. Generator loss: 0.6991192102432251, Discriminator loss: 1.3819447755813599.
# Time for epoch 161 is 30.255465030670166 sec. Generator loss: 0.6990311741828918, Discriminator loss: 1.381935715675354.
# Time for epoch 162 is 30.337952613830566 sec. Generator loss: 0.6989296674728394, Discriminator loss: 1.3820204734802246.
# Time for epoch 163 is 30.122355222702026 sec. Generator loss: 0.6991902589797974, Discriminator loss: 1.381778597831726.
# Time for epoch 164 is 30.318188905715942 sec. Generator loss: 0.6991128921508789, Discriminator loss: 1.3817577362060547.
# Time for epoch 165 is 30.43528699874878 sec. Generator loss: 0.6991104483604431, Discriminator loss: 1.3819348812103271.
# Time for epoch 166 is 30.223071813583374 sec. Generator loss: 0.6990856528282166, Discriminator loss: 1.3818281888961792.
# Time for epoch 167 is 30.172670125961304 sec. Generator loss: 0.6990758180618286, Discriminator loss: 1.3818029165267944.
# Time for epoch 168 is 30.25966167449951 sec. Generator loss: 0.6992324590682983, Discriminator loss: 1.3817269802093506.
# Time for epoch 169 is 30.293562173843384 sec. Generator loss: 0.6991711854934692, Discriminator loss: 1.3818774223327637.
# Time for epoch 170 is 29.841277360916138 sec. Generator loss: 0.6991493105888367, Discriminator loss: 1.3818281888961792.
# Time for epoch 171 is 29.898131608963013 sec. Generator loss: 0.6991446614265442, Discriminator loss: 1.3817650079727173.
# Time for epoch 172 is 30.53710675239563 sec. Generator loss: 0.6991584300994873, Discriminator loss: 1.3817744255065918.
# Time for epoch 173 is 30.008463382720947 sec. Generator loss: 0.6992263793945312, Discriminator loss: 1.3817816972732544.
# Time for epoch 174 is 30.6066632270813 sec. Generator loss: 0.6991862654685974, Discriminator loss: 1.3817203044891357.
# Time for epoch 175 is 30.227139949798584 sec. Generator loss: 0.6991717219352722, Discriminator loss: 1.3818292617797852.
# Time for epoch 176 is 30.347801446914673 sec. Generator loss: 0.6992857456207275, Discriminator loss: 1.3816996812820435.
# Time for epoch 177 is 30.332109689712524 sec. Generator loss: 0.6994089484214783, Discriminator loss: 1.381614089012146.
# Time for epoch 178 is 30.231220960617065 sec. Generator loss: 0.6991086006164551, Discriminator loss: 1.381873607635498.
# Time for epoch 179 is 30.357563972473145 sec. Generator loss: 0.6993498802185059, Discriminator loss: 1.3815948963165283.
# Time for epoch 180 is 30.63716983795166 sec. Generator loss: 0.6994093060493469, Discriminator loss: 1.3814888000488281.
# Time for epoch 181 is 30.046123027801514 sec. Generator loss: 0.699308454990387, Discriminator loss: 1.3816379308700562.
# Time for epoch 182 is 30.367712259292603 sec. Generator loss: 0.6992986798286438, Discriminator loss: 1.3815747499465942.
# Time for epoch 183 is 30.06637167930603 sec. Generator loss: 0.6993216276168823, Discriminator loss: 1.3816174268722534.
# Time for epoch 184 is 30.49893093109131 sec. Generator loss: 0.6992348432540894, Discriminator loss: 1.381783127784729.
# Time for epoch 185 is 30.20736050605774 sec. Generator loss: 0.6993046402931213, Discriminator loss: 1.381666898727417.
# Time for epoch 186 is 30.56872057914734 sec. Generator loss: 0.6992698311805725, Discriminator loss: 1.3818235397338867.
# Time for epoch 187 is 30.204699516296387 sec. Generator loss: 0.6994057297706604, Discriminator loss: 1.3816050291061401.
# Time for epoch 188 is 30.664323329925537 sec. Generator loss: 0.6994100213050842, Discriminator loss: 1.3814460039138794.
# Time for epoch 189 is 30.026344776153564 sec. Generator loss: 0.6994442343711853, Discriminator loss: 1.3814942836761475.
# Time for epoch 190 is 30.53018832206726 sec. Generator loss: 0.6994008421897888, Discriminator loss: 1.3814690113067627.
# Time for epoch 191 is 30.208557844161987 sec. Generator loss: 0.6994438171386719, Discriminator loss: 1.3814979791641235.
# Time for epoch 192 is 41.449687480926514 sec. Generator loss: 0.6994443535804749, Discriminator loss: 1.3814690113067627.
# Time for epoch 193 is 30.801709175109863 sec. Generator loss: 0.6994792222976685, Discriminator loss: 1.3814218044281006.
# Time for epoch 194 is 30.47940707206726 sec. Generator loss: 0.6995068788528442, Discriminator loss: 1.3815213441848755.
# Time for epoch 195 is 30.259339809417725 sec. Generator loss: 0.6995450258255005, Discriminator loss: 1.3814313411712646.
# Time for epoch 196 is 30.261909246444702 sec. Generator loss: 0.6995015144348145, Discriminator loss: 1.3813879489898682.
# Time for epoch 197 is 30.490644454956055 sec. Generator loss: 0.6996009945869446, Discriminator loss: 1.3813599348068237.
# Time for epoch 198 is 30.68123984336853 sec. Generator loss: 0.6994602084159851, Discriminator loss: 1.3815032243728638.
# Time for epoch 199 is 30.21206259727478 sec. Generator loss: 0.6995981931686401, Discriminator loss: 1.3813602924346924.
# Time for epoch 200 is 30.9047749042511 sec. Generator loss: 0.6996162533760071, Discriminator loss: 1.3813093900680542.
# Time for epoch 201 is 30.345873594284058 sec. Generator loss: 0.6996396780014038, Discriminator loss: 1.3813197612762451.
# Time for epoch 202 is 30.72247576713562 sec. Generator loss: 0.6996821761131287, Discriminator loss: 1.38130521774292.
# Time for epoch 203 is 30.376201629638672 sec. Generator loss: 0.6996084451675415, Discriminator loss: 1.3813196420669556.
# Time for epoch 204 is 30.341366052627563 sec. Generator loss: 0.6996689438819885, Discriminator loss: 1.3812941312789917.
# Time for epoch 205 is 30.565420866012573 sec. Generator loss: 0.6997572183609009, Discriminator loss: 1.3812512159347534.
# Time for epoch 206 is 30.327569007873535 sec. Generator loss: 0.6995444297790527, Discriminator loss: 1.3813846111297607.
# Time for epoch 207 is 30.54208731651306 sec. Generator loss: 0.6996685266494751, Discriminator loss: 1.3813992738723755.
# Time for epoch 208 is 30.25940489768982 sec. Generator loss: 0.699657678604126, Discriminator loss: 1.3811638355255127.
# Time for epoch 209 is 30.238835096359253 sec. Generator loss: 0.6998260021209717, Discriminator loss: 1.3811334371566772.
# Time for epoch 210 is 30.325552940368652 sec. Generator loss: 0.6996617317199707, Discriminator loss: 1.381343960762024.
# Time for epoch 211 is 29.86385202407837 sec. Generator loss: 0.6997195482254028, Discriminator loss: 1.3812062740325928.
# Time for epoch 212 is 30.419629335403442 sec. Generator loss: 0.6997513175010681, Discriminator loss: 1.3811770677566528.
# Time for epoch 213 is 30.12319302558899 sec. Generator loss: 0.6998428702354431, Discriminator loss: 1.3812106847763062.
# Time for epoch 214 is 30.37502932548523 sec. Generator loss: 0.6998676657676697, Discriminator loss: 1.3811545372009277.
# Time for epoch 215 is 30.344613313674927 sec. Generator loss: 0.6998224854469299, Discriminator loss: 1.3811908960342407.
# Time for epoch 216 is 30.317867517471313 sec. Generator loss: 0.6998182535171509, Discriminator loss: 1.3811107873916626.
# Time for epoch 217 is 30.444082021713257 sec. Generator loss: 0.6998739242553711, Discriminator loss: 1.3810700178146362.
# Time for epoch 218 is 30.289355516433716 sec. Generator loss: 0.6998447775840759, Discriminator loss: 1.3811280727386475.
# Time for epoch 219 is 30.122514009475708 sec. Generator loss: 0.6999732255935669, Discriminator loss: 1.3811184167861938.
# Time for epoch 220 is 30.315868139266968 sec. Generator loss: 0.7000060081481934, Discriminator loss: 1.3811649084091187.
# Time for epoch 221 is 30.331788063049316 sec. Generator loss: 0.6998393535614014, Discriminator loss: 1.381123661994934.
# Time for epoch 222 is 30.294787406921387 sec. Generator loss: 0.6999452114105225, Discriminator loss: 1.3810880184173584.
# Time for epoch 223 is 30.10969090461731 sec. Generator loss: 0.6999428272247314, Discriminator loss: 1.3810518980026245.
# Time for epoch 224 is 30.469433307647705 sec. Generator loss: 0.6999498009681702, Discriminator loss: 1.38113272190094.
# Time for epoch 225 is 30.368306398391724 sec. Generator loss: 0.6999821066856384, Discriminator loss: 1.381135106086731.
# Time for epoch 226 is 30.53341555595398 sec. Generator loss: 0.7000373601913452, Discriminator loss: 1.3810158967971802.
# Time for epoch 227 is 30.266541957855225 sec. Generator loss: 0.7000768780708313, Discriminator loss: 1.381057858467102.
# Time for epoch 228 is 30.13635563850403 sec. Generator loss: 0.6999765634536743, Discriminator loss: 1.3811261653900146.
# Time for epoch 229 is 30.21116065979004 sec. Generator loss: 0.7000473141670227, Discriminator loss: 1.3809936046600342.
# Time for epoch 230 is 30.214513301849365 sec. Generator loss: 0.7000735998153687, Discriminator loss: 1.380949854850769.
# Time for epoch 231 is 30.55293035507202 sec. Generator loss: 0.700031042098999, Discriminator loss: 1.3811553716659546.
# Time for epoch 232 is 30.113081216812134 sec. Generator loss: 0.7000284194946289, Discriminator loss: 1.381107211112976.
# Time for epoch 233 is 30.23949098587036 sec. Generator loss: 0.7000671625137329, Discriminator loss: 1.3810107707977295.
# Time for epoch 234 is 30.323896169662476 sec. Generator loss: 0.700194776058197, Discriminator loss: 1.3808503150939941.
# Time for epoch 235 is 30.237777948379517 sec. Generator loss: 0.7001380324363708, Discriminator loss: 1.3809891939163208.
# Time for epoch 236 is 30.66749596595764 sec. Generator loss: 0.7001326680183411, Discriminator loss: 1.3810386657714844.
# Time for epoch 237 is 30.243112325668335 sec. Generator loss: 0.6999837160110474, Discriminator loss: 1.3810162544250488.
# Time for epoch 238 is 30.227510690689087 sec. Generator loss: 0.7000870108604431, Discriminator loss: 1.3811306953430176.
# Time for epoch 239 is 30.19019317626953 sec. Generator loss: 0.7001577019691467, Discriminator loss: 1.380947232246399.
# Time for epoch 240 is 30.144071102142334 sec. Generator loss: 0.7000634074211121, Discriminator loss: 1.3811081647872925.
# Time for epoch 241 is 30.631779193878174 sec. Generator loss: 0.700089693069458, Discriminator loss: 1.3810006380081177.
# Time for epoch 242 is 29.91036033630371 sec. Generator loss: 0.7001011371612549, Discriminator loss: 1.3810375928878784.
# Time for epoch 243 is 30.47670030593872 sec. Generator loss: 0.7003264427185059, Discriminator loss: 1.3808348178863525.
# Time for epoch 244 is 30.287622213363647 sec. Generator loss: 0.7002475261688232, Discriminator loss: 1.3809031248092651.
# Time for epoch 245 is 30.277493953704834 sec. Generator loss: 0.70027095079422, Discriminator loss: 1.3807766437530518.
# Time for epoch 246 is 30.701668977737427 sec. Generator loss: 0.70025235414505, Discriminator loss: 1.380914568901062.
# Time for epoch 247 is 31.180628538131714 sec. Generator loss: 0.7003183960914612, Discriminator loss: 1.380782961845398.
# Time for epoch 248 is 33.23075294494629 sec. Generator loss: 0.7002788186073303, Discriminator loss: 1.3808516263961792.
# Time for epoch 249 is 33.57746362686157 sec. Generator loss: 0.700433075428009, Discriminator loss: 1.3807567358016968.
# Time for epoch 250 is 32.87691283226013 sec. Generator loss: 0.7003113031387329, Discriminator loss: 1.3807646036148071.
# Time for epoch 251 is 31.02241849899292 sec. Generator loss: 0.7003499269485474, Discriminator loss: 1.3807510137557983.
# Time for epoch 252 is 30.11078977584839 sec. Generator loss: 0.7003288865089417, Discriminator loss: 1.3808238506317139.
# Time for epoch 253 is 30.854299545288086 sec. Generator loss: 0.7002926468849182, Discriminator loss: 1.3808832168579102.
# Time for epoch 254 is 32.111912965774536 sec. Generator loss: 0.7003758549690247, Discriminator loss: 1.3808774948120117.
# Time for epoch 255 is 30.502374172210693 sec. Generator loss: 0.7003216743469238, Discriminator loss: 1.3808460235595703.
# Time for epoch 256 is 30.73645520210266 sec. Generator loss: 0.700355589389801, Discriminator loss: 1.3807957172393799.
# Time for epoch 257 is 30.698379278182983 sec. Generator loss: 0.7003365755081177, Discriminator loss: 1.3808205127716064.
# Time for epoch 258 is 30.423409700393677 sec. Generator loss: 0.7004202604293823, Discriminator loss: 1.3806710243225098.
# Time for epoch 259 is 30.462889432907104 sec. Generator loss: 0.7003538608551025, Discriminator loss: 1.3808202743530273.
# Time for epoch 260 is 30.77214479446411 sec. Generator loss: 0.7004092931747437, Discriminator loss: 1.3807051181793213.
# Time for epoch 261 is 32.60282611846924 sec. Generator loss: 0.7005124092102051, Discriminator loss: 1.380657434463501.
# Time for epoch 262 is 31.14835548400879 sec. Generator loss: 0.7003881335258484, Discriminator loss: 1.3808040618896484.
# Time for epoch 263 is 30.401155471801758 sec. Generator loss: 0.700507640838623, Discriminator loss: 1.3806862831115723.
# Time for epoch 264 is 30.25146460533142 sec. Generator loss: 0.7003653645515442, Discriminator loss: 1.3808441162109375.
# Time for epoch 265 is 29.926765203475952 sec. Generator loss: 0.7004137635231018, Discriminator loss: 1.3807787895202637.
# Time for epoch 266 is 30.630465984344482 sec. Generator loss: 0.7004656195640564, Discriminator loss: 1.3807696104049683.
# Time for epoch 267 is 31.66322112083435 sec. Generator loss: 0.7004696726799011, Discriminator loss: 1.380662441253662.
# Time for epoch 268 is 30.573652505874634 sec. Generator loss: 0.7005230784416199, Discriminator loss: 1.3806219100952148.
# Time for epoch 269 is 31.878334522247314 sec. Generator loss: 0.7004314064979553, Discriminator loss: 1.3807003498077393.
# Time for epoch 270 is 32.73446345329285 sec. Generator loss: 0.7005020380020142, Discriminator loss: 1.38068687915802.
# Time for epoch 271 is 31.931280612945557 sec. Generator loss: 0.700427770614624, Discriminator loss: 1.3807320594787598.
# Time for epoch 272 is 30.85936737060547 sec. Generator loss: 0.7005682587623596, Discriminator loss: 1.380662202835083.
# Time for epoch 273 is 30.511061191558838 sec. Generator loss: 0.7005305290222168, Discriminator loss: 1.3807404041290283.
# Time for epoch 274 is 30.121435403823853 sec. Generator loss: 0.700585126876831, Discriminator loss: 1.3805962800979614.
# Time for epoch 275 is 29.8338623046875 sec. Generator loss: 0.7004899382591248, Discriminator loss: 1.3806170225143433.
# Time for epoch 276 is 29.946001052856445 sec. Generator loss: 0.7005676031112671, Discriminator loss: 1.3807246685028076.
# Time for epoch 277 is 29.673656702041626 sec. Generator loss: 0.7005639672279358, Discriminator loss: 1.3806040287017822.
# Time for epoch 278 is 30.046730756759644 sec. Generator loss: 0.7007045149803162, Discriminator loss: 1.3804149627685547.
# Time for epoch 279 is 30.155033588409424 sec. Generator loss: 0.700579047203064, Discriminator loss: 1.38053297996521.
# Time for epoch 280 is 30.294507265090942 sec. Generator loss: 0.7006852030754089, Discriminator loss: 1.3804792165756226.
# Time for epoch 281 is 29.769514322280884 sec. Generator loss: 0.7007842659950256, Discriminator loss: 1.380384087562561.
# Time for epoch 282 is 30.31769347190857 sec. Generator loss: 0.7007144093513489, Discriminator loss: 1.3805558681488037.
# Time for epoch 283 is 30.675448656082153 sec. Generator loss: 0.7007814645767212, Discriminator loss: 1.3804415464401245.
# Time for epoch 284 is 32.21717643737793 sec. Generator loss: 0.7007284760475159, Discriminator loss: 1.3804895877838135.
# Time for epoch 285 is 33.99741077423096 sec. Generator loss: 0.7007878422737122, Discriminator loss: 1.3805065155029297.
# Time for epoch 286 is 32.407209396362305 sec. Generator loss: 0.700715184211731, Discriminator loss: 1.3805032968521118.
# Time for epoch 287 is 31.91136384010315 sec. Generator loss: 0.7009101510047913, Discriminator loss: 1.3803733587265015.
# Time for epoch 288 is 30.49081015586853 sec. Generator loss: 0.7007430791854858, Discriminator loss: 1.3804304599761963.
# Time for epoch 289 is 30.456288814544678 sec. Generator loss: 0.7007539868354797, Discriminator loss: 1.3805162906646729.
# Time for epoch 290 is 30.405413389205933 sec. Generator loss: 0.7007135152816772, Discriminator loss: 1.3805004358291626.
# Time for epoch 291 is 30.534780025482178 sec. Generator loss: 0.7008301615715027, Discriminator loss: 1.3804086446762085.
# Time for epoch 292 is 32.52350950241089 sec. Generator loss: 0.70099276304245, Discriminator loss: 1.3802251815795898.
# Time for epoch 293 is 33.72318363189697 sec. Generator loss: 0.7008152008056641, Discriminator loss: 1.3803894519805908.
# Time for epoch 294 is 32.721779346466064 sec. Generator loss: 0.7008840441703796, Discriminator loss: 1.3804278373718262.
# Time for epoch 295 is 31.331350564956665 sec. Generator loss: 0.7007538080215454, Discriminator loss: 1.3804998397827148.
# Time for epoch 296 is 32.90983462333679 sec. Generator loss: 0.7009571194648743, Discriminator loss: 1.3803682327270508.
# Time for epoch 297 is 32.01247811317444 sec. Generator loss: 0.7009044289588928, Discriminator loss: 1.3803926706314087.
# Time for epoch 298 is 30.755518198013306 sec. Generator loss: 0.7008342742919922, Discriminator loss: 1.3805242776870728.
# Time for epoch 299 is 31.04755663871765 sec. Generator loss: 0.7008261680603027, Discriminator loss: 1.3803902864456177.
# Time for epoch 300 is 31.004240036010742 sec. Generator loss: 0.7009466886520386, Discriminator loss: 1.380393385887146.
# Time for epoch 301 is 31.2096164226532 sec. Generator loss: 0.7008373141288757, Discriminator loss: 1.3803560733795166.
# Time for epoch 302 is 30.643956899642944 sec. Generator loss: 0.7010341286659241, Discriminator loss: 1.3802484273910522.
# Time for epoch 303 is 30.77641224861145 sec. Generator loss: 0.7009891867637634, Discriminator loss: 1.3802860975265503.
# Time for epoch 304 is 30.609127521514893 sec. Generator loss: 0.7010198831558228, Discriminator loss: 1.3802193403244019.
# Time for epoch 305 is 30.30040693283081 sec. Generator loss: 0.7011097073554993, Discriminator loss: 1.3802251815795898.
# Time for epoch 306 is 30.15625286102295 sec. Generator loss: 0.7010783553123474, Discriminator loss: 1.3801349401474.
# Time for epoch 307 is 30.192251682281494 sec. Generator loss: 0.7010427117347717, Discriminator loss: 1.380337119102478.
# Time for epoch 308 is 29.964200973510742 sec. Generator loss: 0.7010840177536011, Discriminator loss: 1.3802776336669922.
# Time for epoch 309 is 30.29700994491577 sec. Generator loss: 0.701207160949707, Discriminator loss: 1.3800753355026245.
# Time for epoch 310 is 30.93858289718628 sec. Generator loss: 0.7010456919670105, Discriminator loss: 1.3803032636642456.
# Time for epoch 311 is 31.11833429336548 sec. Generator loss: 0.7011126279830933, Discriminator loss: 1.3801803588867188.
# Time for epoch 312 is 30.653660535812378 sec. Generator loss: 0.7010558247566223, Discriminator loss: 1.3802570104599.
# Time for epoch 313 is 30.99698495864868 sec. Generator loss: 0.7011037468910217, Discriminator loss: 1.3801854848861694.
# Time for epoch 314 is 31.096607446670532 sec. Generator loss: 0.7010855674743652, Discriminator loss: 1.3801531791687012.
# Time for epoch 315 is 30.512346982955933 sec. Generator loss: 0.7011572122573853, Discriminator loss: 1.3801648616790771.
# Time for epoch 316 is 30.85235905647278 sec. Generator loss: 0.701170027256012, Discriminator loss: 1.3801113367080688.
# Time for epoch 317 is 30.39898681640625 sec. Generator loss: 0.7013682126998901, Discriminator loss: 1.3798854351043701.
# Time for epoch 318 is 30.219179391860962 sec. Generator loss: 0.7011462450027466, Discriminator loss: 1.380091667175293.
# Time for epoch 319 is 30.77866291999817 sec. Generator loss: 0.7012791633605957, Discriminator loss: 1.3799585103988647.
# Time for epoch 320 is 30.826324462890625 sec. Generator loss: 0.7012856602668762, Discriminator loss: 1.3800262212753296.
# Time for epoch 321 is 30.48966383934021 sec. Generator loss: 0.7013928294181824, Discriminator loss: 1.3799117803573608.
# Time for epoch 322 is 30.791053533554077 sec. Generator loss: 0.7013588547706604, Discriminator loss: 1.379996657371521.
# Time for epoch 323 is 30.981101036071777 sec. Generator loss: 0.7015143036842346, Discriminator loss: 1.379868507385254.
# Time for epoch 324 is 30.63744854927063 sec. Generator loss: 0.7014992833137512, Discriminator loss: 1.3798201084136963.
# Time for epoch 325 is 30.903164386749268 sec. Generator loss: 0.7014831304550171, Discriminator loss: 1.3799716234207153.
# Time for epoch 326 is 30.93038773536682 sec. Generator loss: 0.7014790177345276, Discriminator loss: 1.379872441291809.
# Time for epoch 327 is 30.940740823745728 sec. Generator loss: 0.7012909054756165, Discriminator loss: 1.3800798654556274.
# Time for epoch 328 is 31.035385608673096 sec. Generator loss: 0.7013448476791382, Discriminator loss: 1.379903793334961.
# Time for epoch 329 is 31.113602876663208 sec. Generator loss: 0.7015964984893799, Discriminator loss: 1.379814863204956.
# Time for epoch 330 is 31.117370128631592 sec. Generator loss: 0.7014297842979431, Discriminator loss: 1.379962682723999.
# Time for epoch 331 is 30.872653007507324 sec. Generator loss: 0.7015065550804138, Discriminator loss: 1.3799126148223877.
# Time for epoch 332 is 30.461952447891235 sec. Generator loss: 0.701495885848999, Discriminator loss: 1.3798828125.
# Time for epoch 333 is 30.570264101028442 sec. Generator loss: 0.7015758156776428, Discriminator loss: 1.3797085285186768.
# Time for epoch 334 is 31.12248206138611 sec. Generator loss: 0.7015730738639832, Discriminator loss: 1.3797402381896973.
# Time for epoch 335 is 31.247100353240967 sec. Generator loss: 0.701516330242157, Discriminator loss: 1.3798730373382568.
# Time for epoch 336 is 30.26668119430542 sec. Generator loss: 0.7015990018844604, Discriminator loss: 1.3798937797546387.
# Time for epoch 337 is 30.172422885894775 sec. Generator loss: 0.7016608715057373, Discriminator loss: 1.3797119855880737.
# Time for epoch 338 is 30.102757453918457 sec. Generator loss: 0.7015387415885925, Discriminator loss: 1.3798105716705322.
# Time for epoch 339 is 30.709370374679565 sec. Generator loss: 0.7016502022743225, Discriminator loss: 1.379751443862915.
# Time for epoch 340 is 30.609912633895874 sec. Generator loss: 0.7016279697418213, Discriminator loss: 1.3797926902770996.
# Time for epoch 341 is 30.478403568267822 sec. Generator loss: 0.7018601894378662, Discriminator loss: 1.3795243501663208.
# Time for epoch 342 is 30.28813672065735 sec. Generator loss: 0.701745331287384, Discriminator loss: 1.3796205520629883.
# Time for epoch 343 is 30.605537176132202 sec. Generator loss: 0.7016755938529968, Discriminator loss: 1.3796863555908203.
# Time for epoch 344 is 31.182112455368042 sec. Generator loss: 0.7017089128494263, Discriminator loss: 1.3797577619552612.
# Time for epoch 345 is 30.34441113471985 sec. Generator loss: 0.7017826437950134, Discriminator loss: 1.3796886205673218.
# Time for epoch 346 is 30.729224681854248 sec. Generator loss: 0.7018312215805054, Discriminator loss: 1.3795374631881714.
# Time for epoch 347 is 30.88754916191101 sec. Generator loss: 0.7018243074417114, Discriminator loss: 1.3795864582061768.
# Time for epoch 348 is 31.20399498939514 sec. Generator loss: 0.701937198638916, Discriminator loss: 1.379349946975708.
# Time for epoch 349 is 30.762935161590576 sec. Generator loss: 0.7017236351966858, Discriminator loss: 1.379721760749817.
# Time for epoch 350 is 30.42300033569336 sec. Generator loss: 0.7019179463386536, Discriminator loss: 1.3794771432876587.
# Time for epoch 351 is 30.151026964187622 sec. Generator loss: 0.7019873261451721, Discriminator loss: 1.379351019859314.
# Time for epoch 352 is 30.4300377368927 sec. Generator loss: 0.7019142508506775, Discriminator loss: 1.3794935941696167.
# Time for epoch 353 is 30.240705490112305 sec. Generator loss: 0.7020026445388794, Discriminator loss: 1.3794268369674683.
# Time for epoch 354 is 30.084577560424805 sec. Generator loss: 0.7018786072731018, Discriminator loss: 1.3795251846313477.
# Time for epoch 355 is 30.291372776031494 sec. Generator loss: 0.7019508481025696, Discriminator loss: 1.379481554031372.
# Time for epoch 356 is 30.73744559288025 sec. Generator loss: 0.7021028399467468, Discriminator loss: 1.3794258832931519.
# Time for epoch 357 is 31.047242403030396 sec. Generator loss: 0.702164888381958, Discriminator loss: 1.3794203996658325.
# Time for epoch 358 is 30.94621968269348 sec. Generator loss: 0.701909601688385, Discriminator loss: 1.3794974088668823.
# Time for epoch 359 is 30.947956800460815 sec. Generator loss: 0.7020893692970276, Discriminator loss: 1.379443645477295.
# Time for epoch 360 is 31.018926858901978 sec. Generator loss: 0.7021250128746033, Discriminator loss: 1.3793193101882935.
# Time for epoch 361 is 30.995969533920288 sec. Generator loss: 0.7020627856254578, Discriminator loss: 1.379331111907959.
# Time for epoch 362 is 30.73086380958557 sec. Generator loss: 0.7021543979644775, Discriminator loss: 1.3793134689331055.
# Time for epoch 363 is 30.95935893058777 sec. Generator loss: 0.7021778225898743, Discriminator loss: 1.3792788982391357.
# Time for epoch 364 is 30.693357706069946 sec. Generator loss: 0.7022436857223511, Discriminator loss: 1.3793514966964722.
# Time for epoch 365 is 30.437493562698364 sec. Generator loss: 0.7022455930709839, Discriminator loss: 1.3792058229446411.
# Time for epoch 366 is 30.953133821487427 sec. Generator loss: 0.7021881341934204, Discriminator loss: 1.379206657409668.
# Time for epoch 367 is 30.053722143173218 sec. Generator loss: 0.7024646401405334, Discriminator loss: 1.3790284395217896.
# Time for epoch 368 is 29.744513034820557 sec. Generator loss: 0.7021900415420532, Discriminator loss: 1.379204273223877.
# Time for epoch 369 is 29.675859212875366 sec. Generator loss: 0.7023907899856567, Discriminator loss: 1.3790740966796875.
# Time for epoch 370 is 29.705137014389038 sec. Generator loss: 0.7023887038230896, Discriminator loss: 1.3792580366134644.
# Time for epoch 371 is 29.80467963218689 sec. Generator loss: 0.7024142146110535, Discriminator loss: 1.379084825515747.
# Time for epoch 372 is 29.987897634506226 sec. Generator loss: 0.7024853825569153, Discriminator loss: 1.3789223432540894.
# Time for epoch 373 is 29.526273012161255 sec. Generator loss: 0.7024160027503967, Discriminator loss: 1.3791661262512207.
# Time for epoch 374 is 30.10427951812744 sec. Generator loss: 0.7025629878044128, Discriminator loss: 1.3788607120513916.
# Time for epoch 375 is 30.05033779144287 sec. Generator loss: 0.7024433612823486, Discriminator loss: 1.3790428638458252.
# Time for epoch 376 is 29.998684883117676 sec. Generator loss: 0.7026004195213318, Discriminator loss: 1.378915548324585.
# Time for epoch 377 is 29.924659490585327 sec. Generator loss: 0.7025723457336426, Discriminator loss: 1.3788437843322754.
# Time for epoch 378 is 29.869194269180298 sec. Generator loss: 0.702591061592102, Discriminator loss: 1.37894868850708.
# Time for epoch 379 is 30.183971166610718 sec. Generator loss: 0.7026881575584412, Discriminator loss: 1.3788281679153442.
# Time for epoch 380 is 29.854849576950073 sec. Generator loss: 0.7026370763778687, Discriminator loss: 1.3789868354797363.
# Time for epoch 381 is 30.21017289161682 sec. Generator loss: 0.702516496181488, Discriminator loss: 1.3789238929748535.
# Time for epoch 382 is 29.971673488616943 sec. Generator loss: 0.7026273012161255, Discriminator loss: 1.3788942098617554.
# Time for epoch 383 is 29.867337703704834 sec. Generator loss: 0.7026671767234802, Discriminator loss: 1.3788971900939941.
# Time for epoch 384 is 32.310659408569336 sec. Generator loss: 0.7026124596595764, Discriminator loss: 1.378917932510376.
# Time for epoch 385 is 32.47706437110901 sec. Generator loss: 0.7028298377990723, Discriminator loss: 1.378678321838379.
# Time for epoch 386 is 31.012418746948242 sec. Generator loss: 0.7026798725128174, Discriminator loss: 1.3788261413574219.
# Time for epoch 387 is 32.55647873878479 sec. Generator loss: 0.7028260231018066, Discriminator loss: 1.3786609172821045.
# Time for epoch 388 is 31.10816526412964 sec. Generator loss: 0.7029998302459717, Discriminator loss: 1.3784667253494263.
# Time for epoch 389 is 32.22544312477112 sec. Generator loss: 0.7029736042022705, Discriminator loss: 1.3785793781280518.
# Time for epoch 390 is 32.559417724609375 sec. Generator loss: 0.7030008435249329, Discriminator loss: 1.3786203861236572.
# Time for epoch 391 is 31.317352771759033 sec. Generator loss: 0.7029630541801453, Discriminator loss: 1.37859046459198.
# Time for epoch 392 is 32.828088998794556 sec. Generator loss: 0.7028462290763855, Discriminator loss: 1.378607988357544.
# Time for epoch 393 is 31.967389583587646 sec. Generator loss: 0.7029921412467957, Discriminator loss: 1.378462553024292.
# Time for epoch 394 is 29.1376793384552 sec. Generator loss: 0.7031044363975525, Discriminator loss: 1.3785094022750854.
# Time for epoch 395 is 29.30431365966797 sec. Generator loss: 0.7031052112579346, Discriminator loss: 1.3784358501434326.
# Time for epoch 396 is 29.22471809387207 sec. Generator loss: 0.7031217217445374, Discriminator loss: 1.3784921169281006.
# Time for epoch 397 is 28.921992540359497 sec. Generator loss: 0.703168511390686, Discriminator loss: 1.3784099817276.
# Time for epoch 398 is 28.824410676956177 sec. Generator loss: 0.7030951380729675, Discriminator loss: 1.3785070180892944.
# Time for epoch 399 is 29.309744596481323 sec. Generator loss: 0.7031440138816833, Discriminator loss: 1.3784897327423096.
# Time for epoch 400 is 28.81415581703186 sec. Generator loss: 0.7030520439147949, Discriminator loss: 1.3785512447357178.
# Time for epoch 401 is 29.37122941017151 sec. Generator loss: 0.7031993269920349, Discriminator loss: 1.3784366846084595.
# Time for epoch 402 is 28.61746907234192 sec. Generator loss: 0.7031727433204651, Discriminator loss: 1.378396987915039.
# Time for epoch 403 is 28.95033097267151 sec. Generator loss: 0.7032588720321655, Discriminator loss: 1.378324270248413.
# Time for epoch 404 is 28.66979718208313 sec. Generator loss: 0.7033758759498596, Discriminator loss: 1.378106713294983.
# Time for epoch 405 is 28.738282918930054 sec. Generator loss: 0.7031900882720947, Discriminator loss: 1.3784042596817017.
# Time for epoch 406 is 28.73133373260498 sec. Generator loss: 0.7033714652061462, Discriminator loss: 1.3781208992004395.
# Time for epoch 407 is 28.946792364120483 sec. Generator loss: 0.7035051584243774, Discriminator loss: 1.3780574798583984.
# Time for epoch 408 is 28.364094257354736 sec. Generator loss: 0.7033514976501465, Discriminator loss: 1.3782813549041748.
# Time for epoch 409 is 29.37965989112854 sec. Generator loss: 0.7033390998840332, Discriminator loss: 1.378272533416748.
# Time for epoch 410 is 29.45627498626709 sec. Generator loss: 0.7034135460853577, Discriminator loss: 1.3782674074172974.
# Time for epoch 411 is 28.84764814376831 sec. Generator loss: 0.7034102082252502, Discriminator loss: 1.378262996673584.
# Time for epoch 412 is 28.221669673919678 sec. Generator loss: 0.7035492658615112, Discriminator loss: 1.3780097961425781.
# Time for epoch 413 is 28.45057702064514 sec. Generator loss: 0.7035250663757324, Discriminator loss: 1.378052830696106.
# Time for epoch 414 is 28.52896738052368 sec. Generator loss: 0.7036009430885315, Discriminator loss: 1.3780525922775269.
# Time for epoch 415 is 27.995929956436157 sec. Generator loss: 0.7037445902824402, Discriminator loss: 1.37800931930542.
# Time for epoch 416 is 28.55485510826111 sec. Generator loss: 0.703575074672699, Discriminator loss: 1.3782159090042114.
# Time for epoch 417 is 27.911983728408813 sec. Generator loss: 0.7037445902824402, Discriminator loss: 1.377960205078125.
# Time for epoch 418 is 28.87567114830017 sec. Generator loss: 0.703630805015564, Discriminator loss: 1.3780491352081299.
# Time for epoch 419 is 28.403961658477783 sec. Generator loss: 0.7038421630859375, Discriminator loss: 1.3777693510055542.
# Time for epoch 420 is 28.3368182182312 sec. Generator loss: 0.7036057114601135, Discriminator loss: 1.3780794143676758.
# Time for epoch 421 is 28.270143747329712 sec. Generator loss: 0.7038130164146423, Discriminator loss: 1.377838134765625.
# Time for epoch 422 is 28.741685390472412 sec. Generator loss: 0.703909158706665, Discriminator loss: 1.377827763557434.
# Time for epoch 423 is 28.23564338684082 sec. Generator loss: 0.7038205862045288, Discriminator loss: 1.3778473138809204.
# Time for epoch 424 is 28.750257968902588 sec. Generator loss: 0.703848123550415, Discriminator loss: 1.3779429197311401.
# Time for epoch 425 is 27.914143323898315 sec. Generator loss: 0.7038260698318481, Discriminator loss: 1.3779380321502686.
# Time for epoch 426 is 28.453760385513306 sec. Generator loss: 0.7039093375205994, Discriminator loss: 1.3778632879257202.
# Time for epoch 427 is 28.466744899749756 sec. Generator loss: 0.70389324426651, Discriminator loss: 1.3777482509613037.
# Time for epoch 428 is 27.983341693878174 sec. Generator loss: 0.7039748430252075, Discriminator loss: 1.377640962600708.
# Time for epoch 429 is 28.662433862686157 sec. Generator loss: 0.7040064334869385, Discriminator loss: 1.3776230812072754.
# Time for epoch 430 is 28.622528791427612 sec. Generator loss: 0.7040030360221863, Discriminator loss: 1.3777703046798706.
# Time for epoch 431 is 27.90410852432251 sec. Generator loss: 0.7040192484855652, Discriminator loss: 1.3776979446411133.
# Time for epoch 432 is 28.837294101715088 sec. Generator loss: 0.7040921449661255, Discriminator loss: 1.377631664276123.
# Time for epoch 433 is 27.995064973831177 sec. Generator loss: 0.7040892243385315, Discriminator loss: 1.377571702003479.
# Time for epoch 434 is 28.38877248764038 sec. Generator loss: 0.7039675712585449, Discriminator loss: 1.3776715993881226.
# Time for epoch 435 is 28.504542350769043 sec. Generator loss: 0.7041847705841064, Discriminator loss: 1.3775877952575684.
# Time for epoch 436 is 27.9446063041687 sec. Generator loss: 0.7041610479354858, Discriminator loss: 1.3774858713150024.
# Time for epoch 437 is 28.79546093940735 sec. Generator loss: 0.7043502330780029, Discriminator loss: 1.3774538040161133.
# Time for epoch 438 is 27.975600719451904 sec. Generator loss: 0.7041826844215393, Discriminator loss: 1.3775559663772583.
# Time for epoch 439 is 28.754688501358032 sec. Generator loss: 0.7043079733848572, Discriminator loss: 1.3773856163024902.
# Time for epoch 440 is 28.119433164596558 sec. Generator loss: 0.7043166756629944, Discriminator loss: 1.3774222135543823.
# Time for epoch 441 is 28.5315101146698 sec. Generator loss: 0.7044852375984192, Discriminator loss: 1.3772939443588257.
# Time for epoch 442 is 28.46317148208618 sec. Generator loss: 0.7043004035949707, Discriminator loss: 1.3773325681686401.
# Time for epoch 443 is 28.576419353485107 sec. Generator loss: 0.7043755650520325, Discriminator loss: 1.3774065971374512.
# Time for epoch 444 is 28.19985008239746 sec. Generator loss: 0.7046492099761963, Discriminator loss: 1.3772125244140625.
# Time for epoch 445 is 28.719517946243286 sec. Generator loss: 0.7045131325721741, Discriminator loss: 1.3772073984146118.
# Time for epoch 446 is 28.225420236587524 sec. Generator loss: 0.7046290040016174, Discriminator loss: 1.3771008253097534.
# Time for epoch 447 is 28.58548092842102 sec. Generator loss: 0.7047039866447449, Discriminator loss: 1.3771711587905884.
# Time for epoch 448 is 28.26313805580139 sec. Generator loss: 0.7044093608856201, Discriminator loss: 1.3773938417434692.
# Time for epoch 449 is 28.1139395236969 sec. Generator loss: 0.7046893835067749, Discriminator loss: 1.3771573305130005.
# Time for epoch 450 is 28.656118392944336 sec. Generator loss: 0.7047130465507507, Discriminator loss: 1.3770430088043213.
# Time for epoch 451 is 28.01044988632202 sec. Generator loss: 0.7046377658843994, Discriminator loss: 1.377105712890625.
# Time for epoch 452 is 28.611148834228516 sec. Generator loss: 0.7047855257987976, Discriminator loss: 1.3772270679473877.
# Time for epoch 453 is 28.788721799850464 sec. Generator loss: 0.7047669887542725, Discriminator loss: 1.3769868612289429.
# Time for epoch 454 is 28.202867031097412 sec. Generator loss: 0.7048659920692444, Discriminator loss: 1.3769822120666504.
# Time for epoch 455 is 28.730287075042725 sec. Generator loss: 0.7049590349197388, Discriminator loss: 1.376878261566162.
# Time for epoch 456 is 28.581958055496216 sec. Generator loss: 0.7048079371452332, Discriminator loss: 1.3770562410354614.
# Time for epoch 457 is 27.979569673538208 sec. Generator loss: 0.7048983573913574, Discriminator loss: 1.3768987655639648.
# Time for epoch 458 is 28.703003406524658 sec. Generator loss: 0.7049750089645386, Discriminator loss: 1.3769668340682983.
# Time for epoch 459 is 28.270017623901367 sec. Generator loss: 0.7050033211708069, Discriminator loss: 1.3769365549087524.
# Time for epoch 460 is 29.12476372718811 sec. Generator loss: 0.7050219774246216, Discriminator loss: 1.3768501281738281.
# Time for epoch 461 is 28.214728355407715 sec. Generator loss: 0.7050797939300537, Discriminator loss: 1.3766841888427734.
# Time for epoch 462 is 28.46460270881653 sec. Generator loss: 0.7051566243171692, Discriminator loss: 1.3766454458236694.
# Time for epoch 463 is 28.382990837097168 sec. Generator loss: 0.7051753997802734, Discriminator loss: 1.3766225576400757.
# Time for epoch 464 is 28.051658630371094 sec. Generator loss: 0.705170750617981, Discriminator loss: 1.3767595291137695.
# Time for epoch 465 is 28.861996173858643 sec. Generator loss: 0.7051252126693726, Discriminator loss: 1.37678861618042.
# Time for epoch 466 is 28.650201320648193 sec. Generator loss: 0.7052760720252991, Discriminator loss: 1.376535415649414.
# Time for epoch 467 is 28.11228346824646 sec. Generator loss: 0.705240786075592, Discriminator loss: 1.3767948150634766.
# Time for epoch 468 is 28.781835079193115 sec. Generator loss: 0.7051836252212524, Discriminator loss: 1.3767350912094116.
# Time for epoch 469 is 28.029625177383423 sec. Generator loss: 0.7052229046821594, Discriminator loss: 1.3766064643859863.
# Time for epoch 470 is 28.371288061141968 sec. Generator loss: 0.705299973487854, Discriminator loss: 1.3766154050827026.
# Time for epoch 471 is 28.51145601272583 sec. Generator loss: 0.7053338885307312, Discriminator loss: 1.3765864372253418.
# Time for epoch 472 is 28.12967872619629 sec. Generator loss: 0.7053354978561401, Discriminator loss: 1.3765512704849243.
# Time for epoch 473 is 28.594948768615723 sec. Generator loss: 0.705500066280365, Discriminator loss: 1.376429796218872.
# Time for epoch 474 is 28.085307836532593 sec. Generator loss: 0.7053882479667664, Discriminator loss: 1.3764493465423584.
# Time for epoch 475 is 29.016799211502075 sec. Generator loss: 0.7055400013923645, Discriminator loss: 1.3763240575790405.
# Time for epoch 476 is 28.56278944015503 sec. Generator loss: 0.7055652737617493, Discriminator loss: 1.376185655593872.
# Time for epoch 477 is 28.406738996505737 sec. Generator loss: 0.7056423425674438, Discriminator loss: 1.3762198686599731.
# Time for epoch 478 is 28.17033839225769 sec. Generator loss: 0.7056491374969482, Discriminator loss: 1.3762822151184082.
# Time for epoch 479 is 28.64625072479248 sec. Generator loss: 0.7057573199272156, Discriminator loss: 1.3759933710098267.
# Time for epoch 480 is 28.34121322631836 sec. Generator loss: 0.7058342695236206, Discriminator loss: 1.3761661052703857.
# Time for epoch 481 is 28.89371967315674 sec. Generator loss: 0.7057713866233826, Discriminator loss: 1.3760658502578735.
# Time for epoch 482 is 28.067615032196045 sec. Generator loss: 0.705792248249054, Discriminator loss: 1.3762242794036865.
# Time for epoch 483 is 28.685735940933228 sec. Generator loss: 0.7057794332504272, Discriminator loss: 1.3761423826217651.
# Time for epoch 484 is 28.254653692245483 sec. Generator loss: 0.7059528231620789, Discriminator loss: 1.3760254383087158.
# Time for epoch 485 is 28.50311255455017 sec. Generator loss: 0.7060763239860535, Discriminator loss: 1.37586510181427.
# Time for epoch 486 is 28.815755128860474 sec. Generator loss: 0.7059422135353088, Discriminator loss: 1.3759219646453857.
# Time for epoch 487 is 28.431320190429688 sec. Generator loss: 0.7061149477958679, Discriminator loss: 1.3759690523147583.
# Time for epoch 488 is 29.213500022888184 sec. Generator loss: 0.7062283754348755, Discriminator loss: 1.375676155090332.
# Time for epoch 489 is 29.18511128425598 sec. Generator loss: 0.7061592936515808, Discriminator loss: 1.3759117126464844.
# Time for epoch 490 is 28.6347758769989 sec. Generator loss: 0.7061066627502441, Discriminator loss: 1.37586510181427.
# Time for epoch 491 is 29.058177709579468 sec. Generator loss: 0.7063440680503845, Discriminator loss: 1.3756471872329712.
# Time for epoch 492 is 29.10095477104187 sec. Generator loss: 0.7062113881111145, Discriminator loss: 1.3757609128952026.
# Time for epoch 493 is 28.96515703201294 sec. Generator loss: 0.7062991857528687, Discriminator loss: 1.375577688217163.
# Time for epoch 494 is 29.054874658584595 sec. Generator loss: 0.7062970399856567, Discriminator loss: 1.375767469406128.
# Time for epoch 495 is 28.813827514648438 sec. Generator loss: 0.7063078880310059, Discriminator loss: 1.3757297992706299.
# Time for epoch 496 is 29.184977054595947 sec. Generator loss: 0.7065993547439575, Discriminator loss: 1.3755029439926147.
# Time for epoch 497 is 28.80146026611328 sec. Generator loss: 0.706652045249939, Discriminator loss: 1.375243902206421.
# Time for epoch 498 is 29.022106647491455 sec. Generator loss: 0.706692636013031, Discriminator loss: 1.3753341436386108.
# Time for epoch 499 is 28.835017204284668 sec. Generator loss: 0.7065620422363281, Discriminator loss: 1.3756145238876343.
# Time for epoch 500 is 28.48030948638916 sec. Generator loss: 0.7065437436103821, Discriminator loss: 1.3755292892456055.

# %% [markdown]
# # Training Results

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
input_vector = tf.random.uniform([len(X_train), 128], minval=0, maxval=1, seed=None)
input_vector.shape
# Out:
# TensorShape([566235, 128])

# %%
fake_data = model_gen.predict(input_vector)
fake_data.shape
# Out:
# (566235, 8)

# %%
fig, ax = plt.subplots(2,4,figsize=(20, 10))
fig.tight_layout(pad=1.7)
plt.subplots_adjust(bottom=0.05, top=0.9)

features_name = ["$p_{t1}$","$\eta_{1}$","$\phi_{1}$","$E_{1}$","$p_{t2}$","$\eta_{2}$","$\phi_{2}$","$E_{2}$"]

for i in range(features_wanted):
    # real signal
    ax[int(i/4),i%4].hist(X_train[:,i],  alpha=0.5, color='r', label='Real Signal', bins=80)
    # fake signal
    ax[int(i/4),i%4].hist(fake_data[:,i],  alpha=0.5, color='b', label='Fake Signal', bins=80)

    ax[int(i/4),i%4].title.set_text(features_name[i])

plt.legend()
plt.show()

# %% [markdown]
# Calculating the first Wasserstein distance between two 1D distributions.

# %%
from scipy.stats import wasserstein_distance
from IPython.display import display, Latex

features_name = ['p_{t1}','\eta_{1}','\phi_{1}','E_{1}','p_{t2}','\eta_{2}','\phi_{2}','E_{2}']

total_wd = 0

for i in range(features_wanted):
    wd = wasserstein_distance(X_train[:, i], fake_data[:, i])
    total_wd += wd

    display(Latex('$' + features_name[i] + ': ' + str(wd) + '$'))

display(Latex('$' + 'Total' + ': ' + str(total_wd) + '$'))
# Out:
# $p_{t1}: 0.001707805638942567$
# $\eta_{1}: 0.03009229804669823$
# $\phi_{1}: 0.04538515422167356$
# $E_{1}: 0.0027213288095691646$
# $p_{t2}: 0.0034957880624764317$
# $\eta_{2}: 0.028038188874134347$
# $\phi_{2}: 0.016042296904649398$
# $E_{2}: 0.0071909586151180475$
# $Total: 0.13467381917326174$

# %% [markdown]
# Calculating the $\chi^2$ distance between the real and fake data distribution:
#
# $$
# \chi^2 = \frac{1}{2}\sum_{i=1}^{n} \frac{\left(A_{i}-B_{i}\right)^{2}}{\left(A_{i}+B_{i}\right)}
# $$
#
# where $A$ is the bin array of the real distribution, $B$ is the bin array of the fake distribution, and $n$ is the number of bins in the bin array.

# %%
# Function to calculate Chi-distace
def chi2_distance(A, B):
  
    # compute the chi-squared distance using above formula
    chi = ((A-B)**2)/(A+B)
    chi = 0.5 * np.nansum(chi) / len(A)
  
    return chi

# %%
from IPython.display import display, Latex

features_name = ['p_{t1}','\eta_{1}','\phi_{1}','E_{1}','p_{t2}','\eta_{2}','\phi_{2}','E_{2}']

for i in range(features_wanted):
    A = np.histogram(X_train[:,i], bins=80)[0]
    B = np.histogram(fake_data[:,i], bins=80)[0]

    chi2 = chi2_distance(A, B)

    display(Latex('$' + features_name[i] + ': ' + str(chi2) + '$'))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """
# $p_{t1}: 3032.0860199031117$
# $\eta_{1}: 15.620238265923678$
# $\phi_{1}: 14.697964988748689$
# $E_{1}: 2244.780788070721$
# $p_{t2}: 2034.2926108122315$
# $\eta_{2}: 15.064129592694604$
# $\phi_{2}: 5.824489571376904$
# $E_{2}: 2976.660512252329$
